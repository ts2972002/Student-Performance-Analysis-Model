# %% [markdown]
# # To understand how student's performance is affected by other varaibles

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
data=pd.read_csv("StudentsPerformance (1).csv")

# %% [markdown]
# # Understanding our data

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Only three integer values

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
data['total']= data['reading score'] + data['math score'] + data['writing score']

# %%
data['average'] = data['total']/3

# %%
print(data['average'])
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average, Length: 1000, dtype: float64

# %%
print(data['total'])
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total, Length: 1000, dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # Cleaning our data

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Observations:
#     There are no missing values in the dataset

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.boxplot(figsize=(20,15))
plt.show()

# %% [markdown]
# # Relationship Analysis

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # Corelation Matrix

# %%
correlation = data.corr()

# %%
sb.heatmap(correlation)

# %%
sb.pairplot(data)

# %% [markdown]
# # Understanding relationships between different varaibles

# %%
sb.distplot(data['math score'])

# %% [markdown]
# # Highest Maths score is between 60-70

# %%
sb.distplot(data['reading score'])

# %% [markdown]
# # Highest Reading score is between 70-80

# %%
sb.distplot(data['writing score'])

# %% [markdown]
# # Highest Writing score is around 70

# %%
sb.scatterplot(x= 'math score', y= 'writing score',hue= 'gender', data=data)

# %%
sb.scatterplot(x= 'math score', y= 'writing score',hue= 'race/ethnicity', data=data)

# %%
sb.scatterplot(x= 'math score', y= 'writing score',hue= 'lunch', data=data)

# %%
sb.scatterplot(x= 'math score', y= 'writing score',hue= 'test preparation course', data=data)

# %%
sb.scatterplot(x= 'test preparation course', y='writing score',hue='gender',data=data)

# %%
sb.scatterplot(x='math score',y='reading score', hue= 'gender', data=data)

# %%
sb.scatterplot(x='math score',y='reading score', hue= 'test preparation course', data=data)

# %%
sb.scatterplot(x='math score',y='reading score', hue= 'lunch', data=data)

# %%
sb.scatterplot(x='math score',y='reading score', hue= 'race/ethnicity', data=data)

# %%
sb.scatterplot(x='math score',y='reading score', hue= 'parental level of education', data=data)

# %%
sb.distplot(data['writing score'],bins=6)

# %%
sb.distplot(data['reading score'],bins=6)

# %%
sb.distplot(data['math score'],bins=6)

# %% [markdown]
# # Changing categorical values to numerical values to find relationship between categorical values

# %%
val=pd.get_dummies(data['gender'])

# %%
val.head()
# Out:
#    female  male
# 0       1     0
# 1       1     0
# 2       1     0
# 3       0     1
# 4       0     1

# %%
val1=pd.get_dummies(data['lunch'])

# %%
val1.head()
# Out:
#    free/reduced  standard
# 0             0         1
# 1             0         1
# 2             0         1
# 3             1         0
# 4             0         1

# %%
val2 =pd.concat((val,val1),axis=1)

# %%
val2.head()
# Out:
#    female  male  free/reduced  standard
# 0       1     0             0         1
# 1       1     0             0         1
# 2       1     0             0         1
# 3       0     1             1         0
# 4       0     1             0         1

# %%
val3 =pd.concat((val2,data),axis=1)

# %%
val3.head()
# Out:
#    female  male  free/reduced  standard  gender race/ethnicity  \
# 0       1     0             0         1  female        group B
# 1       1     0             0         1  female        group C
# 2       1     0             0         1  female        group B
# 3       0     1             1         0    male        group A
# 4       0     1             0         1    male        group C
#
#   parental level of education         lunch test preparation course  \
# 0           bachelor's degree      standard                    none
# 1                some college      standard               completed
# 2             master's degree      standard                    none
# 3          associate's degree  free/reduced                    none
# 4                some college      standard                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# ...

# %% [markdown]
# # Finding relationship between categorical values(first convert themto numerical values 0 and 1 then find the relationship between them)

# %%
sb.scatterplot(x='female',y='male', hue= 'lunch', data=val3)

# %%
sb.scatterplot(x='female',y='male', hue= 'race/ethnicity', data=val3)

# %%
sb.scatterplot(x='female',y='male', hue= 'parental level of education', data=val3)

# %% [markdown]
# # Training the data

# %%
x=data[['reading score','math score']]
y=data['writing score']

# %%
x
# Out:
#      reading score  math score
# 0               72          72
# 1               90          69
# 2               95          90
# 3               57          47
# 4               78          76
# ..             ...         ...
# 995             99          88
# 996             55          62
# 997             71          59
# 998             78          68
# 999             86          77
#
# [1000 rows x 2 columns]

# %%
y
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 800

# %%
len(x_test)
# Out:
# 200

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
clf.predict(x_test)
# Out:
# array([80.85511492, 77.74839233, 60.80495788, 66.15195546, 61.7208428 ,
#        81.07064294, 72.17242351, 80.84167171, 52.44100466, 67.84452103,
#        90.745543  , 35.4481329 , 38.99935473, 94.84447426, 56.17176041,
#        59.09894909, 77.35333039, 96.23174486, 75.67420804, 63.73214655,
#        47.12089351, 73.57313732, 89.19218171, 51.90673846, 68.92649665,
#        76.51376922, 79.7731393 , 64.58515095, 56.62970288, 85.94625484,
#        53.21768531, 73.16463218, 21.59797782, 88.81056299, 87.5893831 ,
#        85.09325045, 38.05658339, 67.70531675, 62.03958099, 87.09111099,
#        71.18021485, 75.41835038, 75.50811734, 66.91519289, 42.15551464,
#        56.46361217, 79.59360538, 67.31025482, 54.54207537, 73.95475604,
#        42.23183839, 66.44380722, 36.50322209, 74.88408418, 66.52013096,
#        63.50317532, 67.9837253 , 61.73428601, 74.34981797, 67.06784038,
#        76.27135477, 65.68056978, 75.52156055, 58.56468289, 61.18657659,
# ...

# %%
y_test
# Out:
# 535    83
# 500    82
# 358    61
# 220    74
# 591    50
#        ..
# 279    57
# 929    51
# 622    52
# 759    77
# 904    84
# Name: writing score, Length: 200, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.9212696696969401

# %% [markdown]
# # Accuracy of our model is 90%
